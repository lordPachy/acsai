# %% [markdown]
# # Histograms
#
# It is possible to plot the distribution of colours with OpenCV.

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

img = cv2.imread("samples/tree.png")
#plt.plot(img)
#plt.show()

# %%
import matplotlib.pyplot as plt

gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
hist = cv2.calcHist([gray], [0], None, [256], [0, 256]) #this takes as paramaters the list of channels and an optional mask which is the region where the histogram is calculated
plt.plot(hist)
plt.show()

# %%
color = ("b", "g", "r")

for i, col in enumerate(color):
    hist = cv2.calcHist([img], [i], None, [256], [0, 255])
    plt.plot(hist, color = col)

# %%
hist_equalized = cv2.equalizeHist(gray)
plt.plot(cv2.cvtColor(hist_equalized, cv2.COLOR_BGR2RGB))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 2
#       1 hist_equalized = cv2.equalizeHist(gray)
# ----> 2 plt.plot(cv2.cvtColor(hist_equalized, cv2.COLOR_BGR2RGB))
#       3 plt.show()
#
# File ~/.cache/pypoetry/virtualenvs/ai_lab-aGYZY7pK-py3.10/lib/python3.10/site-packages/matplotlib/pyplot.py:3590, in plot(scalex, scaley, data, *args, **kwargs)
#    3582 @_copy_docstring_and_deprecators(Axes.plot)
#    3583 def plot(
#    3584     *args: float | ArrayLike | str,
#    (...)
#    3588     **kwargs,
#    3589 ) -> list[Line2D]:
# -> 3590     return gca().plot(
#    3591         *args,
#    3592         scalex=scalex,
#    3593         scaley=scaley,
#    3594         **({"data": data} if data is not None else {}),
#    3595         **kwargs,
#    3596     )
#
# ...
